# %% [markdown]
# <h1>Занятие 3. Вычисления

# %% [markdown]
# <h3>1. Целочисленная арифметика

# %%
print(17 / 3)   # выведет 5.66666666667
print(17 // 3)  # выведет 5
print(17 % 3)   # выведет 2

# %% [markdown]
# <h3>2. Действительные числа

# %%
x = float(input())
print(x)

# %% [markdown]
# <h3>3. Библиотека math

# %%
import math

x = math.ceil(4.2)
y = math.ceil(4.8)
print(x)
print(y)
# Out:
# 5
# 5

# %%
from math import ceil
 
x = 7 / 2
y = ceil(x)
print(y)
# Out:
# 4

# %%
from math import *
 
x = 7 / 2
y = ceil(x)
print(y)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1>Задачки

# %% [markdown]
# <ul><li>Дано натуральное число. Выведите его последнюю цифру.</li>
# <li>Дано положительное действительное число X. Выведите его дробную часть.</li>
# </ul>
